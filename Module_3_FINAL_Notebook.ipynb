# %%
import sqlite3        #import relevant materials
import numpy as np
import pandas as pd

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %%
conn = sqlite3.connect('database-2.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Our first question: Does being home increase your odds of winning according to bookmakers?

# %% [markdown]
# First, We extract the data regarding every single match and the odds of each team across 4 different sports books: Bet 365, Bet&Win, Interwetten, and Ladbrokes.

# %%
c.execute('''SELECT season, date, match_api_id, home_team_api_id, away_team_api_id, B365H, B365D, B365A, BWH, BWD, BWA, IWH, IWD, IWA, LBH, LBD, LBA from Match''')

# %%
Odds = pd.DataFrame(c.fetchall())

# %%
Odds = Odds.rename(columns = {0: 'Season', 1: 'Date', 2: 'Match API', 3: 'Home Team', 4: 'Away Team', 5: 'Bet 365 Home Win Odds', 6: 'Bet 365 Draw Odds',  7: 'Bet 365 Away Win Odds', 8: 'Bet&Win Home Win Odds', 9: 'Bet&Win Draw Odds', 10: 'Bet&Win Away Win Odds', 11: 'Interwetten Home Win Odds', 12: 'Interwetten Draw Odds', 13: 'Interwetten Away Win Odds', 14: 'Ladbrokes Home Win Odds', 15: 'Ladbrokes Draw Odds', 16: 'Ladbrokes Away Win Odds'})

# %%
c.execute('''SELECT * FROM Team ''')

# %%
Teams = pd.DataFrame(c.fetchall())

# %%
Teams = Teams.rename(columns = {1: 'Team ID', 2: 'FIFA Team ID', 3: 'Team Full Name', 4: 'Team Short Name'})

# %%
test = []
team_name = []
for x in tqdm(range(len(Teams))):
    test.append(Teams['Team ID'][x])
    team_name.append(Teams['Team Full Name'][x])
# Out:
# HBox(children=(IntProgress(value=0, max=299), HTML(value='')))

# %%
for x in tqdm(range(len(test))):
    Odds = Odds.replace(test[x], team_name[x])
    
# With this for loop, we are replacing the Team ID which is provided from the table "Match" and replacing it with
# the actual team name from the table "Team"
# Out:
# HBox(children=(IntProgress(value=0, max=299), HTML(value='')))

# %%
Odds = Odds.dropna()

# %%
Man_City_Home = Odds.loc[Odds['Home Team'] == 'Manchester City']

Man_City_Away = Odds.loc[Odds['Away Team'] == 'Manchester City'] 

Man_City_frames = [Man_City_Home, Man_City_Away]

Man_City_Games = pd.concat(Man_City_frames)

Man_City_Games_2008_2009 = Man_City_Games.loc[Man_City_Games['Season'] == '2008/2009']

# %%
Bet_365_Home_Odds = []
Bet_365_Away_Odds = []
Bet_Win_Home_Odds = []
Bet_Win_Away_Odds = []
Interwetten_Home_Odds = []
Interwetten_Away_Odds = []
Ladbrokes_Home_Odds = []
Ladbrokes_Away_Odds = []
opponent = []
for x in Man_City_Games_2008_2009['Home Team']:
    for y in Man_City_Games_2008_2009['Away Team']:
        if x == 'Manchester City':
            pass
        elif x == y:
            a = round(Man_City_Games_2008_2009.loc[Man_City_Games_2008_2009['Away Team'] == x]['Bet 365 Home Win Odds'].item(),3)
            Bet_365_Home_Odds.append(a)
            b = round(Man_City_Games_2008_2009.loc[Man_City_Games_2008_2009['Away Team'] == x]['Bet&Win Home Win Odds'].item(),3)
            Bet_Win_Home_Odds.append(b)
            c = round(Man_City_Games_2008_2009.loc[Man_City_Games_2008_2009['Away Team'] == x]['Interwetten Home Win Odds'].item(),3)
            Interwetten_Home_Odds.append(c)
            d = round(Man_City_Games_2008_2009.loc[Man_City_Games_2008_2009['Away Team'] == x]['Ladbrokes Home Win Odds'].item(),3)
            Ladbrokes_Home_Odds.append(d)
            opponent.append(x)
            e = round(Man_City_Games_2008_2009.loc[Man_City_Games_2008_2009['Home Team'] == y]['Bet 365 Away Win Odds'].item(),3)
            Bet_365_Away_Odds.append(e)
            f = round(Man_City_Games_2008_2009.loc[Man_City_Games_2008_2009['Home Team'] == y]['Bet&Win Away Win Odds'].item(),3)
            Bet_Win_Away_Odds.append(f)
            g = round(Man_City_Games_2008_2009.loc[Man_City_Games_2008_2009['Home Team'] == y]['Interwetten Away Win Odds'].item(),3)
            Interwetten_Away_Odds.append(g)
            h = round(Man_City_Games_2008_2009.loc[Man_City_Games_2008_2009['Home Team'] == y]['Ladbrokes Away Win Odds'].item(),3)
            Ladbrokes_Away_Odds.append(h)
            opponent.append(x)

# %%
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
ManC_Bet365_Home_Odds = np.array(Bet_365_Home_Odds)
ManC_Bet365_Away_Odds = np.array(Bet_365_Away_Odds)

# %%
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(6,5)})
sns.distplot(ManC_Bet365_Home_Odds) # Blue distribution
sns.distplot(ManC_Bet365_Away_Odds) # Orange distribution

# %% [markdown]
# As we see above, we placed the distribution of Manchester City Home Odds for Bet 365 during the 2008/2009 Season with the Man City Away Odds for Bet 365 during the same season. Visually, it is easy to see that when Man City was home, they often had a better chance of winning (or lower odds) compared to away games, where you can see the distribution be pushed out even as far as above 9.

# %% [markdown]
# ### Our $H_{0}$ for this question is: There is no difference between the odds when Manchester City is Home or Away

# %% [markdown]
# ### Our $H_{1}$ for this question is: There is a significant difference between the odds when Manchester City is Home or Away

# %% [markdown]
# ## Calculating the t-statistic
# When comparing the difference between groups, we can calculate the two-sample t-statistic like so:
#
# $$\large t = \frac{\bar{x}_{1} - \bar{x}_{2}}{\sqrt{s^{2}_{p} (\frac{1}{n_{1}} + \frac{1}{n_{2}}) }    }  $$
#
# Where $s^{2}_{p}$ is the pooled sample variance, calculated as:
#
# $$\large s^{2}_{p}  = \frac{(n_{1} -1)s^{2}_{1} +  (n_{2} -1)s^{2}_{2}}{n_{1} + n_{2} + 2}  $$
#
# Where $s^{2}_{1}$ and $s^{2}_{2}$ are the variances for each sample given by the formula
# $$ \large s^{2} = \frac{\sum_{i=1}^{n}(x_{i} - \bar{x})^{2}}{n-1} $$

# %%
def sample_variance(sample):
    sample_mean = np.mean(sample)
    return np.sum((sample - sample_mean) **2)/ (len(sample) -1)

# %%
def pooled_variance(sample1, sample2):
    n_1, n_2 = len(sample1), len(sample2)
    var_1, var_2 = sample_variance(sample1), sample_variance(sample2)
    return ((n_1-1) * var_1 + (n_2-1)* var_2)/((n_1 + n_2)-2)

# %%
def twosample_tstatistic(expr, ctrl):
    exp_mean, ctrl_mean = np.mean(expr), np.mean(ctrl)
    pool_var = pooled_variance(expr, ctrl)
    n_e, n_c = len(expr), len(ctrl)
    num = exp_mean - ctrl_mean
    denom = np.sqrt(pool_var * ((1/n_e)+(1/n_c)))
    return num / denom

t_stat = twosample_tstatistic(ManC_Bet365_Home_Odds, ManC_Bet365_Away_Odds)
t_stat
# Out:
# -3.0600530354504083

# %% [markdown]
# From the functions above, we were able to calculate the t-statics and run a two-sample t-test. A two-sample t-test is used to determine if two population means are equal, which was our null hypothesis.

# %%
def visualize_t(t_stat, info1, info2):

    
    fig = plt.figure(figsize=(8,5))
    ax = fig.gca()
    # generate points on the x axis between -4 and 4:
    xs = np.linspace(-4, 4, 500)

    # use stats.t.pdf to get values on the probability density function for the t-distribution
    
    ys= stats.t.pdf(xs, (info1+info2-2), 0, 1)
    ax.plot(xs, ys, linewidth=3, color='darkred')

    ax.axvline(t_stat, color='black', linestyle='--', lw=5)
    ax.axvline(-t_stat, color='black', linestyle='--', lw=5)

    plt.show()
    return None

info1 = len(ManC_Bet365_Home_Odds)
info2 = len(ManC_Bet365_Away_Odds)
visualize_t(t_stat, info1, info2)

# %% [markdown]
# The t-distribution above shows a standard distribution with vertical lines identifying the t-stat that signifies our "rejection region". If any of our data was to fall in the region, we would have to our null hypothesis.
#
# We use stats.ttest_ind function to calculate the p-value

# %%
stats.ttest_ind(ManC_Bet365_Home_Odds, ManC_Bet365_Away_Odds)
# Out:
# Ttest_indResult(statistic=-3.0600530354504083, pvalue=0.004164693434394226)

# %% [markdown]
# ### With a p-value < .05, we can reject our null hypothesis and accept that there is a significant difference between Manchester City's odds when they are playing home versus when they are playing away.

# %% [markdown]
#  # Our next question: Does a higher defensive aggression result in a higher winning percentage?

# %% [markdown]
# #### They say that defense wins championships...now we actually get to prove it!

# %% [markdown]
# From our data set, we took the team FIFA statistics for the season in question and compared it to the team's winning percentage in that year. Clearly, we must operate under the assumption that FIFA does an accurate job at predicting/assessing each team's defense

# %%
import sqlite3
import numpy as np
conn = sqlite3.connect('database-2.sqlite')
c = conn.cursor()

# %%
c.execute('''SELECT team_api_id, date, defencePressure, defencePressureClass, defenceAggression, defenceAggressionClass, defenceTeamWidth, defenceTeamWidthClass, defenceDefenderLineClass, buildUpPlaySpeed, buildUpPlayPassing,chanceCreationPassing, chanceCreationCrossing, chanceCreationShooting from Team_Attributes''')

# %%
Attributes = pd.DataFrame(c.fetchall())

Attributes = Attributes.rename(columns = {0: 'Team ID', 1: 'Date', 2: 'Defense Pressure', 3: 'Defense Pressure Class', 4: 'Defense Aggression', 5: 'Defense Aggression Class', 6: 'Defense Team Width', 7: 'Defense Team Width Class', 8: 'Defense Defender Class', 9: 'Build Up Speed', 10: 'Build Up Passing', 11: 'Chance Creation Passing', 12: 'Chance Creation Crossing', 13: 'Chance Creation Shooting'})

# %%
for x in range(len(test)):
    Attributes = Attributes.replace(test[x], team_name[x])

# %%
Attributes.head()
# Out:
#     Team ID                 Date  Defense Pressure Defense Pressure Class  \
# 0  FC Aarau  2010-02-22 00:00:00                50                 Medium
# 1  FC Aarau  2014-09-19 00:00:00                47                 Medium
# 2  FC Aarau  2015-09-10 00:00:00                47                 Medium
# 3  Aberdeen  2010-02-22 00:00:00                60                 Medium
# 4  Aberdeen  2011-02-22 00:00:00                47                 Medium
#
#    Defense Aggression Defense Aggression Class  Defense Team Width  \
# 0                  55                    Press                  45
# 1                  44                    Press                  54
# 2                  44                    Press                  54
# 3                  70                   Double                  70
# 4                  47                    Press                  52
#
#   Defense Team Width Class Defense Defender Class  Build Up Speed  \
# 0                   Normal                  Cover              60
# 1                   Normal                  Cover              52
# 2                   Normal                  Cover              47
# 3                     Wide                  Cover              70
# 4                   Normal                  Cover              47
#
#    Build Up Passing  Chance Creation Passing  Chance Creation Crossing  \
# 0                50                       60                        65
# 1                56                       54                        63
# 2                54                       54                        63
# 3                70                       70                        70
# 4                52                       53                        48
#
#    Chance Creation Shooting
# 0                        55
# 1                        64
# 2                        64
# 3                        70
# 4                        52

# %% [markdown]
# ### From the information above, I first took all the Attributes from the FIFA game. I have matched them to each team name with each year and their different statistics for that year.

# %% [markdown]
# ### Now, we are going to compile the winning percentage for each team.

# %%
c.execute('''SELECT season, date, match_api_id, home_team_api_id, away_team_api_id, home_team_goal, away_team_goal from Match''')

Scores = pd.DataFrame(c.fetchall())

Scores = Scores.rename(columns = {0: 'Season', 1: 'Date', 2: 'Match API', 3: 'Home Team', 4: 'Away Team', 5: 'Home Team Goal', 6: 'Away Team Goal'})

for x in range(len(test)):
    Scores = Scores.replace(test[x], team_name[x])

Scores['Winning Team'] = ''

Scores['Losing Team'] = ''

# %%
for x in tqdm(range(len(Scores['Season']))):
    if Scores['Home Team Goal'][x] > Scores['Away Team Goal'][x]:
        Scores.loc[x,'Winning Team'] = Scores.loc[x,'Home Team']
    elif Scores['Home Team Goal'][x] < Scores.loc[x, 'Away Team Goal']:
        Scores.loc[x,'Winning Team'] = Scores.loc[x, 'Away Team']
    else:
        Scores.loc[x,'Winning Team'] = 'Draw'
# Out:
# HBox(children=(IntProgress(value=0, max=25979), HTML(value='')))

# %%
for x in tqdm(range(len(Scores['Season']))):
    if Scores['Home Team Goal'][x] > Scores['Away Team Goal'][x]:
        Scores.loc[x,'Losing Team'] = Scores.loc[x,'Away Team']
    elif Scores['Home Team Goal'][x] < Scores.loc[x, 'Away Team Goal']:
        Scores.loc[x,'Losing Team'] = Scores.loc[x, 'Home Team']
    else:
        Scores.loc[x,'Losing Team'] = 'Draw'
# Out:
# HBox(children=(IntProgress(value=0, max=25979), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-03282898853b> in <module>
#       5         Scores.loc[x,'Losing Team'] = Scores.loc[x, 'Home Team']
#       6     else:
# ----> 7         Scores.loc[x,'Losing Team'] = 'Draw'
#       8
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     618                 # scalar
#     619                 for item in labels:
# --> 620                     setter(item, value)
#     621
#     622         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in setter(item, v)
#     541
#     542                 # reset the sliced object if unique
# --> 543                 self.obj[item] = s
#     544
#     545             def can_do_equal_len():
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3605
#    3606         if isinstance(value, Series):
# -> 3607             value = reindexer(value)
#    3608
#    3609         elif isinstance(value, DataFrame):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reindexer(value)
#    3587
#    3588             if value.index.equals(self.index) or not len(self.index):
# -> 3589                 value = value._values.copy()
#    3590             else:
#    3591
#
# KeyboardInterrupt:

# %%
Attributes['Year'] = ''

for x in tqdm(range(len(Attributes))):
    Attributes['Year'][x] = Attributes['Date'][x][:4]

# %%
Season_2010_2011 = Scores.loc[Scores['Season'] == '2010/2011']

d = Season_2010_2011.groupby('Winning Team').size()

d = d.to_dict()

d.pop('Draw')

# %%
Wins_2010 = [v for v in d.values()]

WTeams_2010 = [x for x in d.keys()]

Season_2010 = pd.DataFrame(WTeams_2010)

Season_2010['Wins'] = Wins_2010

Season_2010 = Season_2010.rename(columns={0:'Team'})

# %%
e = Season_2010_2011.groupby('Losing Team').size()

e = e.to_dict()

e.pop('Draw')

Losses_2010 = [v for v in e.values()]

LTeams_2010 = [x for x in e.keys()]

# %%
len(Wins_2010), len(Losses_2010)

# %% [markdown]
# ###### WHAT?! There are more results in wins than losses? How could this be possible?!
#
# ...unfortunately for us, an "undefeated team" lies amongst us. This means we are going to have to do some digging and find who that undefeated team is, add them to the losses list with a 0, find that missing team, then adjust accordingly.

# %%
LTeams_2010.append(0)

# %%
TEST = pd.DataFrame(data = WTeams_2010)
TEST[1] = LTeams_2010

# %% [markdown]
# Let's start digging...

# %%
TEST[0:50]

# %% [markdown]
# Not in the first 50...let's check the next 50...

# %%
TEST[50:100]

# %% [markdown]
# ## BANG!
#
# FC Porto had an undefeated season in 2010. So we have to add them to the Losers list and add a value of 0 for them at the end, and then we can continue...

# %%
LTeams_2010.remove(0)
LTeams_2010.append('FC Porto')
Losses_2010.append(0)

# %%
Final_2010_Losses = pd.DataFrame({'Team': LTeams_2010, 'Team Loss': Losses_2010})

# %%
Final_2010_Losses = Final_2010_Losses.sort_values('Team')

# %%
Final_2010_Losses = Final_2010_Losses.reset_index()
Final_2010_Losses = Final_2010_Losses.drop(['index'], axis=1)

Season_2010['Loss'] = Final_2010_Losses['Team Loss']

# %%
Season_2010.head()

# %% [markdown]
# Perfect! Now we continue to account for all draws in 2010 Season...

# %%
Season_2010_2011 = Season_2010_2011.reset_index()

Season_2010_2011 = Season_2010_2011.drop(['index'], axis=1)

Draws_2010 = []
for x in range(len(Season_2010_2011['Season'])):
    if Season_2010_2011.loc[x, 'Winning Team'] == 'Draw':
        Draws_2010.append(Season_2010_2011.loc[x, 'Home Team'])
        Draws_2010.append(Season_2010_2011.loc[x, 'Away Team'])

        
# This for loop adds each time a team draws to a list, then we use "Counter" to count how many times each team is listed
# and add them to a dictionary!

from collections import Counter        
draws = Counter(Draws_2010)

draws_2010 = {}
for key, value in draws.items():
    draws_2010[key] = value
    
Season_2010['Draws'] = ''

# %%
Final_2010_Draws = pd.DataFrame(draws_2010.items())

Final_2010_Draws  = Final_2010_Draws .sort_values(0)

Final_2010_Draws  = Final_2010_Draws .reset_index()

Final_2010_Draws  = Final_2010_Draws .drop(['index'], axis=1)

Season_2010['Draws'] = Final_2010_Draws [1]

Season_2010 = Season_2010.reset_index()

Season_2010 = Season_2010.drop(['index'], axis=1)

# %%
Season_2010.head()

# %% [markdown]
# Perfect! Now let's create a function that will automatically add winning percentage to our table!

# %%
def winning_percent(season):
    season['Winning %'] = 100*((season['Wins']+(season['Draws']/2))/(season['Wins']+(season['Draws']+(season['Loss']))))

# %%
pd.set_option('precision', 2) # Limits our percentage to just two decimal places

winning_percent(Season_2010)

# %%
Season_2010.head()

# %% [markdown]
# Excellent! Now that we have the winning % calculated, we have to merge the table with the team's statistics with the table we just made.

# %%
Defense_2010 = Attributes.loc[Attributes['Year']=='2010']

Defense_2010 = Defense_2010.sort_values('Team ID')

Defense_2010 = Defense_2010.reset_index()

Defense_2010 = Defense_2010.drop(['index'], axis=1)

Defense_2010 = Defense_2010.drop(Defense_2010.index[156]) #To save the trouble of showing the problem, this data set double counted a team, so we deleted them with this code

Defense_2010 = Defense_2010.reset_index()

Defense_2010 = Defense_2010.drop(['index'], axis=1)

# %%
Season_2010['Defense Pressure'] = 0    # With this code, we are adding columns to our Winning % table that we will fill in with info from the Attributes table
Season_2010['Defense Aggression'] = 0
Season_2010['Defense Team Width'] = 0
Season_2010['Build Up Speed'] = 0
Season_2010['Build Up Passing'] = 0
Season_2010['Chance Creation Passing'] = 0
Season_2010['Chance Creation Crossing'] = 0
Season_2010['Chance Creation Shooting'] = 0

Season_2010 = Season_2010.reset_index()
Season_2010 = Season_2010.drop(['index'], axis=1)

# %%
def defense_type(year, season):       # This function will automatically run any Attributes table created with any winning% table create to give a final table with all the info!
    for team in tqdm(season['Team']):
        for x in year['Team ID']:
            if team == x:
                season.loc[season['Team'] == team, 'Defense Pressure'] = year.loc[year['Team ID'] == x, 'Defense Pressure'].item()
                season.loc[season['Team'] == team, 'Defense Aggression'] = year.loc[year['Team ID'] == x, 'Defense Aggression'].item()
                season.loc[season['Team'] == team, 'Defense Team Width'] = year.loc[year['Team ID'] == x, 'Defense Team Width'].item()
                season.loc[season['Team'] == team, 'Build Up Speed'] = year.loc[year['Team ID'] == x, 'Build Up Speed'].item()
                season.loc[season['Team'] == team, 'Build Up Passing'] = year.loc[year['Team ID'] == x, 'Build Up Passing'].item()
                season.loc[season['Team'] == team, 'Chance Creation Passing'] = year.loc[year['Team ID'] == x, 'Chance Creation Passing'].item()
                season.loc[season['Team'] == team, 'Chance Creation Crossing'] = year.loc[year['Team ID'] == x, 'Chance Creation Crossing'].item()
                season.loc[season['Team'] == team, 'Chance Creation Shooting'] = year.loc[year['Team ID'] == x, 'Chance Creation Shooting'].item()
            else:
                pass
    return season

# %%
defense_type(Defense_2010, Season_2010)

# %% [markdown]
# ## Fantastic!
#
# Now, let's check the correlation table and Pearson value to see if our hypothesis of high defense aggression means high winning %, or, in official terms:
#
# ### Our $H_{0}$ for this question is: There is no relatinship between defense aggression and winning %
#
# ### Our $H_{1}$ for this question is: There is a correlation between defense aggression and winning %

# %%
Season_2010.corr()

# %%
import scipy

scipy.stats.pearsonr(Season_2010['Winning %'], Season_2010['Defense Aggression'])

# %% [markdown]
# ### Heartbreaking...
#
# As noted above, our correlation is low, and our p-value is even higher, showing that we cannot reject our null hypothesis. The scatterplot below demonstrates more clearly how poor this hypothesis was.

# %%
import matplotlib.pyplot as plt
plt.scatter(Season_2010['Winning %'], Season_2010['Defense Pressure']);
plt.xlabel('Winning%')
plt.ylabel('Defense Pressure')

# %% [markdown]
# # Question #3: If defense doesn't win championships, does offense?
#
# Since the one metric for defense didn't work, we will try all 3 for offense.

# %%
scipy.stats.pearsonr(Season_2010['Winning %'], Season_2010['Chance Creation Passing'])

# %%
scipy.stats.pearsonr(Season_2010['Winning %'], Season_2010['Chance Creation Crossing'])

# %%
scipy.stats.pearsonr(Season_2010['Winning %'], Season_2010['Chance Creation Shooting'])

# %%
#Question #4: Do home games make a difference on the home teams chance of winning?

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import distplot
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
import math
import statistics 
import scipy
import scipy.stats as stats
from scipy.stats.distributions import norm
from scipy.stats import ttest_ind
from scipy.stats import ttest_rel
from scipy.stats import wilcoxon,kurtosis,skew
from statistics import stdev,mean
import sqlite3

#Getting what we need to Start

# %%
conn = sqlite3.connect('database-2.sqlite')
c = conn.cursor()
a = conn.cursor()
b = conn.cursor()
d = conn.cursor()
e = conn.cursor()
f = conn.cursor()

# %%
c.execute("""select home_team_goal, away_team_goal,away_team_api_id,
match_api_id, Match.date, Team.team_long_name,count(home_team_api_id) as HomeWins FROM Match 
JOIN Team ON home_team_api_id= Team.team_api_id
WHERE home_team_goal > away_team_goal
group by home_team_api_id
ORDER BY team_long_name;""")
#SQL for HOMEWINS

# %%
HomeWinsdf=pd.DataFrame(c.fetchall())
HomeWinsdf.columns=['home_team_goal','away_team_goal','away_team_api_id','match_api_id','Match.date','team_long_name','Home_Wins']
HomeWinsdf.head()
#Homewins dataframe
# Out:
#    home_team_goal  away_team_goal  away_team_api_id  match_api_id  \
# 0               3               0              9788        856962
# 1               2               1              9904        499422
# 2               3               2              8178        674495
# 3               3               0              8358        674353
# 4               1               0              9851       1019691
#
#             Match.date        team_long_name  Home_Wins
# 0  2010-10-30 00:00:00  1. FC Kaiserslautern          8
# 1  2008-11-07 00:00:00            1. FC Köln         32
# 2  2010-03-07 00:00:00        1. FC Nürnberg         30
# 3  2009-10-24 00:00:00       1. FSV Mainz 05         55
# 4  2011-12-18 00:00:00            AC Ajaccio         16

# %%
HomeWinsdf.loc[HomeWinsdf['team_long_name']=='Widzew Łódź']
# Out:
#      home_team_goal  away_team_goal  away_team_api_id  match_api_id  \
# 287               4               1              1957        838488
# 288               2               1              8030        506653
#
#               Match.date team_long_name  Home_Wins
# 287  2010-10-23 00:00:00    Widzew Łódź         23
# 288  2008-12-05 00:00:00    Widzew Łódź          7

# %%
f.execute("""select home_team_goal, away_team_goal,match_api_id, date, Team.team_long_name, 
count(home_team_api_id) as HomeDraws FROM Match 
JOIN Team ON home_team_api_id= Team.team_api_id
WHERE away_team_goal = home_team_goal
GROUP BY home_team_api_id
ORDER BY team_long_name;""")
#SQL HOMETEAM Draws

# %%
HomeDrawsdf=pd.DataFrame(f.fetchall())
HomeDrawsdf.columns = ('home_team_goal','away_team_goal','match_api_id','date','team_long_name','HomeDraws')
HomeDrawsdf.head()
#Homedraws dataframe with teams
# Out:
#    home_team_goal  away_team_goal  match_api_id                 date  \
# 0               3               3        856989  2010-11-13 00:00:00
# 1               1               1        499475  2009-01-31 00:00:00
# 2               2               2        674364  2009-10-31 00:00:00
# 3               2               2        674270  2009-08-08 00:00:00
# 4               2               2       1019589  2011-11-19 00:00:00
#
#          team_long_name  HomeDraws
# 0  1. FC Kaiserslautern         11
# 1            1. FC Köln         31
# 2        1. FC Nürnberg         21
# 3       1. FSV Mainz 05         29
# 4            AC Ajaccio         19

# %%
d.execute("""select match_api_id, home_team_goal,
Team.team_long_name, home_team_api_id, count(Team.team_api_id) as NumOfHomeGames
from Match
JOIN Team ON home_team_api_id= Team.team_api_id
group by home_team_api_id
order by team_long_name;""")
#SQL # of games

# %%
NumberOfHomeGamesdf=pd.DataFrame(d.fetchall())
NumberOfHomeGamesdf.columns=('match_api_id','home_team_goal','team_long_name','home_team_api_id','NumOfHomeGames')
NumberOfHomeGamesdf.head()
# of games Dataframe
# Out:
#    match_api_id  home_team_goal        team_long_name  home_team_api_id  \
# 0        856962               3  1. FC Kaiserslautern              8350
# 1        499404               0            1. FC Köln              8722
# 2        674268               1        1. FC Nürnberg              8165
# 3        674270               2       1. FSV Mainz 05              9905
# 4       1019336               0            AC Ajaccio              8576
#
#    NumOfHomeGames
# 0              34
# 1             102
# 2              85
# 3             119
# 4              57

# %%
HomeGame_Data = pd.merge(HomeDrawsdf,HomeWinsdf,on='team_long_name')
HomeGame_Data2 = pd.merge(HomeGame_Data,NumberOfHomeGamesdf,on='team_long_name')
HomeGame_Data2real= HomeGame_Data2[['team_long_name','HomeDraws','Home_Wins','NumOfHomeGames']]
HomeGame_Data2real
#Putting new Dataframe merging Home game wins, draws, number of games, with team names.
# Out:
#                team_long_name  HomeDraws  Home_Wins  NumOfHomeGames
# 0        1. FC Kaiserslautern         11          8              34
# 1                  1. FC Köln         31         32             102
# 2              1. FC Nürnberg         21         30              85
# 3             1. FSV Mainz 05         29         55             119
# 4                  AC Ajaccio         19         16              57
# 5            AC Arles-Avignon          6          2              19
# 6               AC Bellinzona         13         17              54
# 7                ADO Den Haag         39         50             136
# 8                  AJ Auxerre         27         31              76
# 9                   AS Monaco         39         53             114
# 10          AS Nancy-Lorraine         29         30              95
# 11           AS Saint-Étienne         40         75             152
# 12                         AZ         26         82             136
# 13                   Aberdeen         38         67             152
# 14       Académica de Coimbra         48         35             124
# 15                       Ajax         24        103             136
# 16                    Amadora          4          7              15
# 17                 Angers SCO          8          6              19
# 18                Arka Gdynia         12         16              45
# 19                    Arsenal         34         97             152
# 20                Aston Villa         50         45             152
# 21                   Atalanta         35         55             132
# 22    Athletic Club de Bilbao         31         80             152
# 23            Atlético Madrid         24        103             152
# 24             BSC Young Boys         34         85             143
# 25                       Bari         10         13              38
# 26        Bayer 04 Leverkusen         34         76             136
# 27               Beerschot AC         25         30              76
# 28            Birmingham City         17         14              38
# 29           Blackburn Rovers         21         29              76
# ..                        ...        ...        ...             ...
# 285               Valencia CF         34         90             152
# 286           Valenciennes FC         34         49             114
# 287             VfB Stuttgart         26         58             136
# 288                VfL Bochum         10          7              34
# 289             VfL Wolfsburg         31         74             136
# 290             Villarreal CF         30         77             133
# 291                   Vitesse         45         60             136
# 292         Vitória Guimarães         36         53             124
# 293           Vitória Setúbal         33         41             124
# 294          Waasland-Beveren         14         14              48
# 295                   Watford          6          6              19
# 296      West Bromwich Albion         34         47             133
# 297           West Ham United         32         55             133
# 298               Widzew Łódź         22         23              60
# 299               Widzew Łódź         22         23              30
# 300               Widzew Łódź         22          7              60
# 301               Widzew Łódź         22          7              30
# 302               Widzew Łódź          9         23              60
# 303               Widzew Łódź          9         23              30
# 304               Widzew Łódź          9          7              60
# 305               Widzew Łódź          9          7              30
# 306            Wigan Athletic         33         28              95
# 307                 Willem II         21         31             102
# 308              Wisła Kraków         26         64             120
# 309   Wolverhampton Wanderers         13         16              57
# 310      Xerez Club Deportivo          4          6              19
# 311            Zagłębie Lubin         27         35              90
# 312         Zawisza Bydgoszcz          5         13              30
# 313  Évian Thonon Gaillard FC         17         29              76
# 314             Śląsk Wrocław         35         59             120
#
# [315 rows x 4 columns]

# %%
a.execute("""select home_team_goal, away_team_goal,match_api_id,home_team_api_id, date, 
Team.team_long_name,Team.team_api_id, count(away_team_api_id) as AwayWins
FROM Match 
JOIN Team ON away_team_api_id= Team.team_api_id
WHERE away_team_goal > home_team_goal
GROUP BY away_team_api_id
ORDER BY team_long_name;""")
#SQL for AWAYWINS

# %%
Awaywinsdf=pd.DataFrame(a.fetchall())
Awaywinsdf.columns=['home_team_goal','away_team_goal','match_api_id','home_team_api_id','date','team_long_name','Team.team_api_id','Away_Wins']
AW= Awaywinsdf[['Team.team_api_id','team_long_name','Away_Wins']]
Awaywinsdf.head()
#Away wins Dataframe
# Out:
#    home_team_goal  away_team_goal  match_api_id  home_team_api_id  \
# 0               1               3        856877              8722
# 1               1               3        499410             10269
# 2               2               3        674379              8721
# 3               0               1        674496              8226
# 4               0               2       1019748              9874
#
#                   date        team_long_name  Team.team_api_id  Away_Wins
# 0  2010-08-21 00:00:00  1. FC Kaiserslautern              8350          9
# 1  2008-11-01 00:00:00            1. FC Köln              8722         28
# 2  2009-11-21 00:00:00        1. FC Nürnberg              8165         19
# 3  2010-03-07 00:00:00       1. FSV Mainz 05              9905         33
# 4  2011-12-21 00:00:00            AC Ajaccio              8576          6

# %%
b.execute("""select home_team_goal, away_team_goal,match_api_id, date, Team.team_long_name, 
count(away_team_api_id) as AwayDraws FROM Match 
JOIN Team ON away_team_api_id= Team.team_api_id
WHERE away_team_goal = home_team_goal
GROUP BY away_team_api_id
ORDER BY team_long_name;""")
#SQL for Away game Draws

# %%
AwayDrawsdf=pd.DataFrame(b.fetchall())
AwayDrawsdf.columns=('home_team_goal','away_team_goal','match_api_id','date','team_long_name','AwayDraws')
AD= AwayDrawsdf[['team_long_name','AwayDraws']]
AwayDrawsdf.head()
#Away games draws dataframe for each team
# Out:
#    home_team_goal  away_team_goal  match_api_id                 date  \
# 0               0               0        857248  2011-03-05 00:00:00
# 1               2               2        499483  2009-02-07 00:00:00
# 2               1               1        674277  2009-08-15 00:00:00
# 3               3               3        674360  2009-10-31 00:00:00
# 4               2               2       1019674  2011-12-10 00:00:00
#
#          team_long_name  AwayDraws
# 0  1. FC Kaiserslautern          7
# 1            1. FC Köln         23
# 2        1. FC Nürnberg         22
# 3       1. FSV Mainz 05         36
# 4            AC Ajaccio         21

# %%
e.execute("""select match_api_id, away_team_goal,
Team.team_long_name, away_team_api_id, count(Team.team_api_id) as NumOfAwayGames
from Match
JOIN Team ON away_team_api_id= Team.team_api_id
group by away_team_api_id
order by team_long_name;""")
#SQL for # of AwayGames

# %%
NumberOfAwayGamesdf=pd.DataFrame(e.fetchall())
NumberOfAwayGamesdf.columns=('match_api_id','away_team_goal','team_long_name','away_team_api_id','NumOfAwayGames')
NumberOfAwayGamesdf.head()
# of Away games Dataframe
# Out:
#    match_api_id  away_team_goal        team_long_name  away_team_api_id  \
# 0        856877               3  1. FC Kaiserslautern              8350
# 1        499320               1            1. FC Köln              8722
# 2        674355               0        1. FC Nürnberg              8165
# 3        674360               3       1. FSV Mainz 05              9905
# 4       1019530               0            AC Ajaccio              8576
#
#    NumOfAwayGames
# 0              34
# 1             102
# 2              85
# 3             119
# 4              57

# %%
NumAG = NumberOfAwayGamesdf[['away_team_api_id','team_long_name','NumOfAwayGames']]
NumAG
#just taking away match_api_id since its grouped by teams not games anymore
# Out:
#      away_team_api_id            team_long_name  NumOfAwayGames
# 0                8350      1. FC Kaiserslautern              34
# 1                8722                1. FC Köln             102
# 2                8165            1. FC Nürnberg              85
# 3                9905           1. FSV Mainz 05             119
# 4                8576                AC Ajaccio              57
# 5              108893          AC Arles-Avignon              19
# 6                6493             AC Bellinzona              54
# 7               10217              ADO Den Haag             136
# 8                8583                AJ Auxerre              76
# 9                9829                 AS Monaco             114
# 10               8481         AS Nancy-Lorraine              95
# 11               9853          AS Saint-Étienne             152
# 12              10229                        AZ             136
# 13               8485                  Aberdeen             152
# 14              10215      Académica de Coimbra             124
# 15               8593                      Ajax             136
# 16              10213                   Amadora              15
# 17               8121                Angers SCO              19
# 18               8322               Arka Gdynia              45
# 19               9825                   Arsenal             152
# 20              10252               Aston Villa             152
# 21               8524                  Atalanta             131
# 22               8315   Athletic Club de Bilbao             152
# 23               9906           Atlético Madrid             152
# 24              10192            BSC Young Boys             143
# 25               9976                      Bari              38
# 26               8178       Bayer 04 Leverkusen             136
# 27               9993              Beerschot AC              76
# 28               8658           Birmingham City              38
# 29               8655          Blackburn Rovers              76
# ..                ...                       ...             ...
# 269              8306             UD Las Palmas              19
# 270              4170  US Boulogne Cote D'Opale              19
# 271              8600                   Udinese             151
# 272              6367          Uniao da Madeira              17
# 273              9771      União de Leiria, SAD              45
# 274              9839                 VVV-Venlo              68
# 275             10267               Valencia CF             152
# 276              9873           Valenciennes FC             114
# 277             10269             VfB Stuttgart             136
# 278              9911                VfL Bochum              34
# 279              8721             VfL Wolfsburg             136
# 280             10205             Villarreal CF             133
# 281              8277                   Vitesse             136
# 282              7844         Vitória Guimarães             124
# 283             10238           Vitória Setúbal             124
# 284              8475          Waasland-Beveren              48
# 285              9817                   Watford              19
# 286              8659      West Bromwich Albion             133
# 287              8654           West Ham United             133
# 288              8024               Widzew Łódź              60
# 289              8244               Widzew Łódź              30
# 290              8528            Wigan Athletic              95
# 291              8525                 Willem II             102
# 292             10265              Wisła Kraków             120
# 293              8602   Wolverhampton Wanderers              57
# 294              9868      Xerez Club Deportivo              19
# 295              8021            Zagłębie Lubin              90
# 296              8027         Zawisza Bydgoszcz              30
# 297              4087  Évian Thonon Gaillard FC              76
# 298              8025             Śląsk Wrocław             120
#
# [299 rows x 3 columns]

# %%
AwayGame_Data = pd.merge(AD,AW, on='team_long_name')
AwayGame_Data
# Out:
#                team_long_name  AwayDraws  Team.team_api_id  Away_Wins
# 0        1. FC Kaiserslautern          7              8350          9
# 1                  1. FC Köln         23              8722         28
# 2              1. FC Nürnberg         22              8165         19
# 3             1. FSV Mainz 05         36              9905         33
# 4                  AC Ajaccio         21              8576          6
# 5            AC Arles-Avignon          5            108893          1
# 6               AC Bellinzona         12              6493          8
# 7                ADO Den Haag         35             10217         29
# 8                  AJ Auxerre         23              8583         22
# 9                   AS Monaco         36              9829         42
# 10          AS Nancy-Lorraine         24              8481         26
# 11           AS Saint-Étienne         42              9853         46
# 12                         AZ         27             10229         58
# 13                   Aberdeen         37              8485         53
# 14       Académica de Coimbra         34             10215         21
# 15                       Ajax         35              8593         78
# 16                    Amadora          6             10213          1
# 17                 Angers SCO          3              8121          7
# 18                Arka Gdynia         14              8322          4
# 19                    Arsenal         39              9825         73
# 20                Aston Villa         38             10252         41
# 21                   Atalanta         34              8524         24
# 22    Athletic Club de Bilbao         40              8315         42
# 23            Atlético Madrid         35              9906         64
# 24             BSC Young Boys         35             10192         57
# 25                       Bari         10              9976          5
# 26        Bayer 04 Leverkusen         32              8178         61
# 27               Beerschot AC         17              9993         10
# 28            Birmingham City          9              8658          7
# 29           Blackburn Rovers         18              8655         13
# ..                        ...        ...               ...        ...
# 275                   Udinese         39              8600         38
# 276          Uniao da Madeira          2              6367          1
# 277      União de Leiria, SAD         12              9771          8
# 278                 VVV-Venlo         12              9839          6
# 279               Valencia CF         40             10267         52
# 280           Valenciennes FC         35              9873         16
# 281             VfB Stuttgart         35             10269         41
# 282                VfL Bochum         11              9911          6
# 283             VfL Wolfsburg         36              8721         43
# 284             Villarreal CF         41             10205         35
# 285                   Vitesse         26              8277         45
# 286         Vitória Guimarães         25              7844         39
# 287           Vitória Setúbal         32             10238         17
# 288          Waasland-Beveren          7              8475         10
# 289                   Watford          3              9817          6
# 290      West Bromwich Albion         39              8659         28
# 291           West Ham United         42              8654         25
# 292               Widzew Łódź         16              8024         10
# 293               Widzew Łódź         16              8244          8
# 294               Widzew Łódź          5              8024         10
# 295               Widzew Łódź          5              8244          8
# 296            Wigan Athletic         19              8528         22
# 297                 Willem II         20              8525         13
# 298              Wisła Kraków         38             10265         44
# 299   Wolverhampton Wanderers         15              8602          9
# 300      Xerez Club Deportivo          6              9868          2
# 301            Zagłębie Lubin         24              8021         24
# 302         Zawisza Bydgoszcz          9              8027          6
# 303  Évian Thonon Gaillard FC         19              4087         16
# 304             Śląsk Wrocław         45              8025         30
#
# [305 rows x 4 columns]

# %%
AwayGame_Data = pd.merge(AD,AW, on='team_long_name')
AwayGame_Data2 = pd.merge(AwayGame_Data,NumAG,on='team_long_name')
AwayGame_Data2real = AwayGame_Data2[['team_long_name','AwayDraws','Team.team_api_id','Away_Wins','NumOfAwayGames']]
AwayGame_Data2real
#Merging new Dataframe for Away wins, draws, number of games, for each team.
# Out:
#                team_long_name  AwayDraws  Team.team_api_id  Away_Wins  \
# 0        1. FC Kaiserslautern          7              8350          9
# 1                  1. FC Köln         23              8722         28
# 2              1. FC Nürnberg         22              8165         19
# 3             1. FSV Mainz 05         36              9905         33
# 4                  AC Ajaccio         21              8576          6
# 5            AC Arles-Avignon          5            108893          1
# 6               AC Bellinzona         12              6493          8
# 7                ADO Den Haag         35             10217         29
# 8                  AJ Auxerre         23              8583         22
# 9                   AS Monaco         36              9829         42
# 10          AS Nancy-Lorraine         24              8481         26
# 11           AS Saint-Étienne         42              9853         46
# 12                         AZ         27             10229         58
# 13                   Aberdeen         37              8485         53
# 14       Académica de Coimbra         34             10215         21
# 15                       Ajax         35              8593         78
# 16                    Amadora          6             10213          1
# 17                 Angers SCO          3              8121          7
# 18                Arka Gdynia         14              8322          4
# 19                    Arsenal         39              9825         73
# 20                Aston Villa         38             10252         41
# 21                   Atalanta         34              8524         24
# 22    Athletic Club de Bilbao         40              8315         42
# 23            Atlético Madrid         35              9906         64
# 24             BSC Young Boys         35             10192         57
# 25                       Bari         10              9976          5
# 26        Bayer 04 Leverkusen         32              8178         61
# 27               Beerschot AC         17              9993         10
# 28            Birmingham City          9              8658          7
# 29           Blackburn Rovers         18              8655         13
# ..                        ...        ...               ...        ...
# 287               Valencia CF         40             10267         52
# 288           Valenciennes FC         35              9873         16
# 289             VfB Stuttgart         35             10269         41
# 290                VfL Bochum         11              9911          6
# 291             VfL Wolfsburg         36              8721         43
# 292             Villarreal CF         41             10205         35
# 293                   Vitesse         26              8277         45
# 294         Vitória Guimarães         25              7844         39
# 295           Vitória Setúbal         32             10238         17
# 296          Waasland-Beveren          7              8475         10
# 297                   Watford          3              9817          6
# 298      West Bromwich Albion         39              8659         28
# 299           West Ham United         42              8654         25
# 300               Widzew Łódź         16              8024         10
# 301               Widzew Łódź         16              8024         10
# 302               Widzew Łódź         16              8244          8
# 303               Widzew Łódź         16              8244          8
# 304               Widzew Łódź          5              8024         10
# 305               Widzew Łódź          5              8024         10
# 306               Widzew Łódź          5              8244          8
# 307               Widzew Łódź          5              8244          8
# 308            Wigan Athletic         19              8528         22
# 309                 Willem II         20              8525         13
# 310              Wisła Kraków         38             10265         44
# 311   Wolverhampton Wanderers         15              8602          9
# 312      Xerez Club Deportivo          6              9868          2
# 313            Zagłębie Lubin         24              8021         24
# 314         Zawisza Bydgoszcz          9              8027          6
# 315  Évian Thonon Gaillard FC         19              4087         16
# 316             Śląsk Wrocław         45              8025         30
#
#      NumOfAwayGames
# 0                34
# 1               102
# 2                85
# 3               119
# 4                57
# 5                19
# 6                54
# 7               136
# 8                76
# 9               114
# 10               95
# 11              152
# 12              136
# 13              152
# 14              124
# 15              136
# 16               15
# 17               19
# 18               45
# 19              152
# 20              152
# 21              131
# 22              152
# 23              152
# 24              143
# 25               38
# 26              136
# 27               76
# 28               38
# 29               76
# ..              ...
# 287             152
# 288             114
# 289             136
# 290              34
# 291             136
# 292             133
# 293             136
# 294             124
# 295             124
# 296              48
# 297              19
# 298             133
# 299             133
# 300              60
# 301              30
# 302              60
# 303              30
# 304              60
# 305              30
# 306              60
# 307              30
# 308              95
# 309             102
# 310             120
# 311              57
# 312              19
# 313              90
# 314              30
# 315              76
# 316             120
#
# [317 rows x 5 columns]

# %%
CombinedHomeandAway= pd.merge(HomeGame_Data2real,AwayGame_Data2real,on='team_long_name')
CombinedHomeandAway
#Final Big merge for Stats for both Away and Home Games for each teams entire recorded results for years 2008-2016
# Out:
#                team_long_name  HomeDraws  Home_Wins  NumOfHomeGames  \
# 0        1. FC Kaiserslautern         11          8              34
# 1                  1. FC Köln         31         32             102
# 2              1. FC Nürnberg         21         30              85
# 3             1. FSV Mainz 05         29         55             119
# 4                  AC Ajaccio         19         16              57
# 5            AC Arles-Avignon          6          2              19
# 6               AC Bellinzona         13         17              54
# 7                ADO Den Haag         39         50             136
# 8                  AJ Auxerre         27         31              76
# 9                   AS Monaco         39         53             114
# 10          AS Nancy-Lorraine         29         30              95
# 11           AS Saint-Étienne         40         75             152
# 12                         AZ         26         82             136
# 13                   Aberdeen         38         67             152
# 14       Académica de Coimbra         48         35             124
# 15                       Ajax         24        103             136
# 16                    Amadora          4          7              15
# 17                 Angers SCO          8          6              19
# 18                Arka Gdynia         12         16              45
# 19                    Arsenal         34         97             152
# 20                Aston Villa         50         45             152
# 21                   Atalanta         35         55             132
# 22    Athletic Club de Bilbao         31         80             152
# 23            Atlético Madrid         24        103             152
# 24             BSC Young Boys         34         85             143
# 25                       Bari         10         13              38
# 26        Bayer 04 Leverkusen         34         76             136
# 27               Beerschot AC         25         30              76
# 28            Birmingham City         17         14              38
# 29           Blackburn Rovers         21         29              76
# ..                        ...        ...        ...             ...
# 453               Widzew Łódź          9         23              30
# 454               Widzew Łódź          9         23              30
# 455               Widzew Łódź          9         23              30
# 456               Widzew Łódź          9         23              30
# 457               Widzew Łódź          9         23              30
# 458               Widzew Łódź          9          7              60
# 459               Widzew Łódź          9          7              60
# 460               Widzew Łódź          9          7              60
# 461               Widzew Łódź          9          7              60
# 462               Widzew Łódź          9          7              60
# 463               Widzew Łódź          9          7              60
# 464               Widzew Łódź          9          7              60
# 465               Widzew Łódź          9          7              60
# 466               Widzew Łódź          9          7              30
# 467               Widzew Łódź          9          7              30
# 468               Widzew Łódź          9          7              30
# 469               Widzew Łódź          9          7              30
# 470               Widzew Łódź          9          7              30
# 471               Widzew Łódź          9          7              30
# 472               Widzew Łódź          9          7              30
# 473               Widzew Łódź          9          7              30
# 474            Wigan Athletic         33         28              95
# 475                 Willem II         21         31             102
# 476              Wisła Kraków         26         64             120
# 477   Wolverhampton Wanderers         13         16              57
# 478      Xerez Club Deportivo          4          6              19
# 479            Zagłębie Lubin         27         35              90
# 480         Zawisza Bydgoszcz          5         13              30
# 481  Évian Thonon Gaillard FC         17         29              76
# 482             Śląsk Wrocław         35         59             120
#
#      AwayDraws  Team.team_api_id  Away_Wins  NumOfAwayGames
# 0            7              8350          9              34
# 1           23              8722         28             102
# 2           22              8165         19              85
# 3           36              9905         33             119
# 4           21              8576          6              57
# 5            5            108893          1              19
# 6           12              6493          8              54
# 7           35             10217         29             136
# 8           23              8583         22              76
# 9           36              9829         42             114
# 10          24              8481         26              95
# 11          42              9853         46             152
# 12          27             10229         58             136
# 13          37              8485         53             152
# 14          34             10215         21             124
# 15          35              8593         78             136
# 16           6             10213          1              15
# 17           3              8121          7              19
# 18          14              8322          4              45
# 19          39              9825         73             152
# 20          38             10252         41             152
# 21          34              8524         24             131
# 22          40              8315         42             152
# 23          35              9906         64             152
# 24          35             10192         57             143
# 25          10              9976          5              38
# 26          32              8178         61             136
# 27          17              9993         10              76
# 28           9              8658          7              38
# 29          18              8655         13              76
# ..         ...               ...        ...             ...
# 453         16              8244          8              30
# 454          5              8024         10              60
# 455          5              8024         10              30
# 456          5              8244          8              60
# 457          5              8244          8              30
# 458         16              8024         10              60
# 459         16              8024         10              30
# 460         16              8244          8              60
# 461         16              8244          8              30
# 462          5              8024         10              60
# 463          5              8024         10              30
# 464          5              8244          8              60
# 465          5              8244          8              30
# 466         16              8024         10              60
# 467         16              8024         10              30
# 468         16              8244          8              60
# 469         16              8244          8              30
# 470          5              8024         10              60
# 471          5              8024         10              30
# 472          5              8244          8              60
# 473          5              8244          8              30
# 474         19              8528         22              95
# 475         20              8525         13             102
# 476         38             10265         44             120
# 477         15              8602          9              57
# 478          6              9868          2              19
# 479         24              8021         24              90
# 480          9              8027          6              30
# 481         19              4087         16              76
# 482         45              8025         30             120
#
# [483 rows x 8 columns]

# %%
CombinedHomeandAway.loc[CombinedHomeandAway['Team.team_api_id']==8024]
# Out:
#     team_long_name  HomeDraws  Home_Wins  NumOfHomeGames  AwayDraws  \
# 410    Widzew Łódź         22         23              60         16
# 411    Widzew Łódź         22         23              60         16
# 414    Widzew Łódź         22         23              60          5
# 415    Widzew Łódź         22         23              60          5
# 418    Widzew Łódź         22         23              30         16
# 419    Widzew Łódź         22         23              30         16
# 422    Widzew Łódź         22         23              30          5
# 423    Widzew Łódź         22         23              30          5
# 426    Widzew Łódź         22          7              60         16
# 427    Widzew Łódź         22          7              60         16
# 430    Widzew Łódź         22          7              60          5
# 431    Widzew Łódź         22          7              60          5
# 434    Widzew Łódź         22          7              30         16
# 435    Widzew Łódź         22          7              30         16
# 438    Widzew Łódź         22          7              30          5
# 439    Widzew Łódź         22          7              30          5
# 442    Widzew Łódź          9         23              60         16
# 443    Widzew Łódź          9         23              60         16
# 446    Widzew Łódź          9         23              60          5
# 447    Widzew Łódź          9         23              60          5
# 450    Widzew Łódź          9         23              30         16
# 451    Widzew Łódź          9         23              30         16
# 454    Widzew Łódź          9         23              30          5
# 455    Widzew Łódź          9         23              30          5
# 458    Widzew Łódź          9          7              60         16
# 459    Widzew Łódź          9          7              60         16
# 462    Widzew Łódź          9          7              60          5
# 463    Widzew Łódź          9          7              60          5
# 466    Widzew Łódź          9          7              30         16
# 467    Widzew Łódź          9          7              30         16
# 470    Widzew Łódź          9          7              30          5
# 471    Widzew Łódź          9          7              30          5
#
#      Team.team_api_id  Away_Wins  NumOfAwayGames
# 410              8024         10              60
# 411              8024         10              30
# 414              8024         10              60
# 415              8024         10              30
# 418              8024         10              60
# 419              8024         10              30
# 422              8024         10              60
# 423              8024         10              30
# 426              8024         10              60
# 427              8024         10              30
# 430              8024         10              60
# 431              8024         10              30
# 434              8024         10              60
# 435              8024         10              30
# 438              8024         10              60
# 439              8024         10              30
# 442              8024         10              60
# 443              8024         10              30
# 446              8024         10              60
# 447              8024         10              30
# 450              8024         10              60
# 451              8024         10              30
# 454              8024         10              60
# 455              8024         10              30
# 458              8024         10              60
# 459              8024         10              30
# 462              8024         10              60
# 463              8024         10              30
# 466              8024         10              60
# 467              8024         10              30
# 470              8024         10              60
# 471              8024         10              30

# %%
np.arange(411,472)
# Out:
# array([411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423,
#        424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436,
#        437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449,
#        450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462,
#        463, 464, 465, 466, 467, 468, 469, 470, 471])

# %%
CombinedHomeandAway.drop(np.arange(411,472), axis = 0, inplace=True)
CombinedHomeandAway
# Out:
#                team_long_name  HomeDraws  Home_Wins  NumOfHomeGames  \
# 0        1. FC Kaiserslautern         11          8              34
# 1                  1. FC Köln         31         32             102
# 2              1. FC Nürnberg         21         30              85
# 3             1. FSV Mainz 05         29         55             119
# 4                  AC Ajaccio         19         16              57
# 5            AC Arles-Avignon          6          2              19
# 6               AC Bellinzona         13         17              54
# 7                ADO Den Haag         39         50             136
# 8                  AJ Auxerre         27         31              76
# 9                   AS Monaco         39         53             114
# 10          AS Nancy-Lorraine         29         30              95
# 11           AS Saint-Étienne         40         75             152
# 12                         AZ         26         82             136
# 13                   Aberdeen         38         67             152
# 14       Académica de Coimbra         48         35             124
# 15                       Ajax         24        103             136
# 16                    Amadora          4          7              15
# 17                 Angers SCO          8          6              19
# 18                Arka Gdynia         12         16              45
# 19                    Arsenal         34         97             152
# 20                Aston Villa         50         45             152
# 21                   Atalanta         35         55             132
# 22    Athletic Club de Bilbao         31         80             152
# 23            Atlético Madrid         24        103             152
# 24             BSC Young Boys         34         85             143
# 25                       Bari         10         13              38
# 26        Bayer 04 Leverkusen         34         76             136
# 27               Beerschot AC         25         30              76
# 28            Birmingham City         17         14              38
# 29           Blackburn Rovers         21         29              76
# ..                        ...        ...        ...             ...
# 390                UD Almería         33         31              95
# 391             UD Las Palmas          5          8              19
# 392  US Boulogne Cote D'Opale          5          4              19
# 393                   Udinese         37         77             151
# 394          Uniao da Madeira          6          6              17
# 395      União de Leiria, SAD          8         15              45
# 396                 VVV-Venlo         16         23              68
# 397               Valencia CF         34         90             152
# 398           Valenciennes FC         34         49             114
# 399             VfB Stuttgart         26         58             136
# 400                VfL Bochum         10          7              34
# 401             VfL Wolfsburg         31         74             136
# 402             Villarreal CF         30         77             133
# 403                   Vitesse         45         60             136
# 404         Vitória Guimarães         36         53             124
# 405           Vitória Setúbal         33         41             124
# 406          Waasland-Beveren         14         14              48
# 407                   Watford          6          6              19
# 408      West Bromwich Albion         34         47             133
# 409           West Ham United         32         55             133
# 472               Widzew Łódź          9          7              30
# 474            Wigan Athletic         33         28              95
# 475                 Willem II         21         31             102
# 476              Wisła Kraków         26         64             120
# 477   Wolverhampton Wanderers         13         16              57
# 478      Xerez Club Deportivo          4          6              19
# 479            Zagłębie Lubin         27         35              90
# 480         Zawisza Bydgoszcz          5         13              30
# 481  Évian Thonon Gaillard FC         17         29              76
# 482             Śląsk Wrocław         35         59             120
#
#      AwayDraws  Team.team_api_id  Away_Wins  NumOfAwayGames
# 0            7              8350          9              34
# 1           23              8722         28             102
# 2           22              8165         19              85
# 3           36              9905         33             119
# 4           21              8576          6              57
# 5            5            108893          1              19
# 6           12              6493          8              54
# 7           35             10217         29             136
# 8           23              8583         22              76
# 9           36              9829         42             114
# 10          24              8481         26              95
# 11          42              9853         46             152
# 12          27             10229         58             136
# 13          37              8485         53             152
# 14          34             10215         21             124
# 15          35              8593         78             136
# 16           6             10213          1              15
# 17           3              8121          7              19
# 18          14              8322          4              45
# 19          39              9825         73             152
# 20          38             10252         41             152
# 21          34              8524         24             131
# 22          40              8315         42             152
# 23          35              9906         64             152
# 24          35             10192         57             143
# 25          10              9976          5              38
# 26          32              8178         61             136
# 27          17              9993         10              76
# 28           9              8658          7              38
# 29          18              8655         13              76
# ..         ...               ...        ...             ...
# 390         13              9865         17              95
# 391          3              8306          4              19
# 392          5              4170          3              19
# 393         39              8600         38             151
# 394          2              6367          1              17
# 395         12              9771          8              45
# 396         12              9839          6              68
# 397         40             10267         52             152
# 398         35              9873         16             114
# 399         35             10269         41             136
# 400         11              9911          6              34
# 401         36              8721         43             136
# 402         41             10205         35             133
# 403         26              8277         45             136
# 404         25              7844         39             124
# 405         32             10238         17             124
# 406          7              8475         10              48
# 407          3              9817          6              19
# 408         39              8659         28             133
# 409         42              8654         25             133
# 472          5              8244          8              60
# 474         19              8528         22              95
# 475         20              8525         13             102
# 476         38             10265         44             120
# 477         15              8602          9              57
# 478          6              9868          2              19
# 479         24              8021         24              90
# 480          9              8027          6              30
# 481         19              4087         16              76
# 482         45              8025         30             120
#
# [420 rows x 8 columns]

# %%
CombinedHomeandAway[CombinedHomeandAway['team_long_name']=='Arsenal']
# Out:
#    team_long_name  HomeDraws  Home_Wins  NumOfHomeGames  AwayDraws  \
# 19        Arsenal         34         97             152         39
#
#     Team.team_api_id  Away_Wins  NumOfAwayGames
# 19              9825         73             152

# %%
CombinedHomeandAway['%HomeWinSuccess']=CombinedHomeandAway.apply(lambda row: row.Home_Wins/row.NumOfHomeGames, axis=1)
CombinedHomeandAway['%AwayWinSuccess']=CombinedHomeandAway.apply(lambda row: row.Away_Wins/row.NumOfAwayGames, axis=1)
CombinedHomeandAway['%HomeDraws']=CombinedHomeandAway.apply(lambda row: row.HomeDraws/row.NumOfHomeGames, axis=1)
CombinedHomeandAway['%AwayDraws']=CombinedHomeandAway.apply(lambda row: row.AwayDraws/row.NumOfAwayGames, axis=1)
CombinedHomeandAway['Difference_of_Wins'] = CombinedHomeandAway['Home_Wins'] - CombinedHomeandAway['Away_Wins']
CombinedHomeandAway
#Created some new columns to Examine more.
# Out:
#                team_long_name  HomeDraws  Home_Wins  NumOfHomeGames  \
# 0        1. FC Kaiserslautern         11          8              34
# 1                  1. FC Köln         31         32             102
# 2              1. FC Nürnberg         21         30              85
# 3             1. FSV Mainz 05         29         55             119
# 4                  AC Ajaccio         19         16              57
# 5            AC Arles-Avignon          6          2              19
# 6               AC Bellinzona         13         17              54
# 7                ADO Den Haag         39         50             136
# 8                  AJ Auxerre         27         31              76
# 9                   AS Monaco         39         53             114
# 10          AS Nancy-Lorraine         29         30              95
# 11           AS Saint-Étienne         40         75             152
# 12                         AZ         26         82             136
# 13                   Aberdeen         38         67             152
# 14       Académica de Coimbra         48         35             124
# 15                       Ajax         24        103             136
# 16                    Amadora          4          7              15
# 17                 Angers SCO          8          6              19
# 18                Arka Gdynia         12         16              45
# 19                    Arsenal         34         97             152
# 20                Aston Villa         50         45             152
# 21                   Atalanta         35         55             132
# 22    Athletic Club de Bilbao         31         80             152
# 23            Atlético Madrid         24        103             152
# 24             BSC Young Boys         34         85             143
# 25                       Bari         10         13              38
# 26        Bayer 04 Leverkusen         34         76             136
# 27               Beerschot AC         25         30              76
# 28            Birmingham City         17         14              38
# 29           Blackburn Rovers         21         29              76
# ..                        ...        ...        ...             ...
# 451               Widzew Łódź          9         23              30
# 452               Widzew Łódź          9         23              30
# 453               Widzew Łódź          9         23              30
# 454               Widzew Łódź          9         23              30
# 455               Widzew Łódź          9         23              30
# 456               Widzew Łódź          9         23              30
# 457               Widzew Łódź          9         23              30
# 458               Widzew Łódź          9          7              60
# 459               Widzew Łódź          9          7              60
# 460               Widzew Łódź          9          7              60
# 461               Widzew Łódź          9          7              60
# 462               Widzew Łódź          9          7              60
# 463               Widzew Łódź          9          7              60
# 464               Widzew Łódź          9          7              60
# 465               Widzew Łódź          9          7              60
# 466               Widzew Łódź          9          7              30
# 467               Widzew Łódź          9          7              30
# 468               Widzew Łódź          9          7              30
# 469               Widzew Łódź          9          7              30
# 470               Widzew Łódź          9          7              30
# 472               Widzew Łódź          9          7              30
# 474            Wigan Athletic         33         28              95
# 475                 Willem II         21         31             102
# 476              Wisła Kraków         26         64             120
# 477   Wolverhampton Wanderers         13         16              57
# 478      Xerez Club Deportivo          4          6              19
# 479            Zagłębie Lubin         27         35              90
# 480         Zawisza Bydgoszcz          5         13              30
# 481  Évian Thonon Gaillard FC         17         29              76
# 482             Śląsk Wrocław         35         59             120
#
#      AwayDraws  Team.team_api_id  Away_Wins  NumOfAwayGames  %HomeWinSuccess  \
# 0            7              8350          9              34         0.235294
# 1           23              8722         28             102         0.313725
# 2           22              8165         19              85         0.352941
# 3           36              9905         33             119         0.462185
# 4           21              8576          6              57         0.280702
# 5            5            108893          1              19         0.105263
# 6           12              6493          8              54         0.314815
# 7           35             10217         29             136         0.367647
# 8           23              8583         22              76         0.407895
# 9           36              9829         42             114         0.464912
# 10          24              8481         26              95         0.315789
# 11          42              9853         46             152         0.493421
# 12          27             10229         58             136         0.602941
# 13          37              8485         53             152         0.440789
# 14          34             10215         21             124         0.282258
# 15          35              8593         78             136         0.757353
# 16           6             10213          1              15         0.466667
# 17           3              8121          7              19         0.315789
# 18          14              8322          4              45         0.355556
# 19          39              9825         73             152         0.638158
# 20          38             10252         41             152         0.296053
# 21          34              8524         24             131         0.416667
# 22          40              8315         42             152         0.526316
# 23          35              9906         64             152         0.677632
# 24          35             10192         57             143         0.594406
# 25          10              9976          5              38         0.342105
# 26          32              8178         61             136         0.558824
# 27          17              9993         10              76         0.394737
# 28           9              8658          7              38         0.368421
# 29          18              8655         13              76         0.381579
# ..         ...               ...        ...             ...              ...
# 451         16              8024         10              30         0.766667
# 452         16              8244          8              60         0.766667
# 453         16              8244          8              30         0.766667
# 454          5              8024         10              60         0.766667
# 455          5              8024         10              30         0.766667
# 456          5              8244          8              60         0.766667
# 457          5              8244          8              30         0.766667
# 458         16              8024         10              60         0.116667
# 459         16              8024         10              30         0.116667
# 460         16              8244          8              60         0.116667
# 461         16              8244          8              30         0.116667
# 462          5              8024         10              60         0.116667
# 463          5              8024         10              30         0.116667
# 464          5              8244          8              60         0.116667
# 465          5              8244          8              30         0.116667
# 466         16              8024         10              60         0.233333
# 467         16              8024         10              30         0.233333
# 468         16              8244          8              60         0.233333
# 469         16              8244          8              30         0.233333
# 470          5              8024         10              60         0.233333
# 472          5              8244          8              60         0.233333
# 474         19              8528         22              95         0.294737
# 475         20              8525         13             102         0.303922
# 476         38             10265         44             120         0.533333
# 477         15              8602          9              57         0.280702
# 478          6              9868          2              19         0.315789
# 479         24              8021         24              90         0.388889
# 480          9              8027          6              30         0.433333
# 481         19              4087         16              76         0.381579
# 482         45              8025         30             120         0.491667
#
#      %AwayWinSuccess  %HomeDraws  %AwayDraws  Difference_of_Wins
# 0           0.264706    0.323529    0.205882                  -1
# 1           0.274510    0.303922    0.225490                   4
# 2           0.223529    0.247059    0.258824                  11
# 3           0.277311    0.243697    0.302521                  22
# 4           0.105263    0.333333    0.368421                  10
# 5           0.052632    0.315789    0.263158                   1
# 6           0.148148    0.240741    0.222222                   9
# 7           0.213235    0.286765    0.257353                  21
# 8           0.289474    0.355263    0.302632                   9
# 9           0.368421    0.342105    0.315789                  11
# 10          0.273684    0.305263    0.252632                   4
# 11          0.302632    0.263158    0.276316                  29
# 12          0.426471    0.191176    0.198529                  24
# 13          0.348684    0.250000    0.243421                  14
# 14          0.169355    0.387097    0.274194                  14
# 15          0.573529    0.176471    0.257353                  25
# 16          0.066667    0.266667    0.400000                   6
# 17          0.368421    0.421053    0.157895                  -1
# 18          0.088889    0.266667    0.311111                  12
# 19          0.480263    0.223684    0.256579                  24
# 20          0.269737    0.328947    0.250000                   4
# 21          0.183206    0.265152    0.259542                  31
# 22          0.276316    0.203947    0.263158                  38
# 23          0.421053    0.157895    0.230263                  39
# 24          0.398601    0.237762    0.244755                  28
# 25          0.131579    0.263158    0.263158                   8
# 26          0.448529    0.250000    0.235294                  15
# 27          0.131579    0.328947    0.223684                  20
# 28          0.184211    0.447368    0.236842                   7
# 29          0.171053    0.276316    0.236842                  16
# ..               ...         ...         ...                 ...
# 451         0.333333    0.300000    0.533333                  13
# 452         0.133333    0.300000    0.266667                  15
# 453         0.266667    0.300000    0.533333                  15
# 454         0.166667    0.300000    0.083333                  13
# 455         0.333333    0.300000    0.166667                  13
# 456         0.133333    0.300000    0.083333                  15
# 457         0.266667    0.300000    0.166667                  15
# 458         0.166667    0.150000    0.266667                  -3
# 459         0.333333    0.150000    0.533333                  -3
# 460         0.133333    0.150000    0.266667                  -1
# 461         0.266667    0.150000    0.533333                  -1
# 462         0.166667    0.150000    0.083333                  -3
# 463         0.333333    0.150000    0.166667                  -3
# 464         0.133333    0.150000    0.083333                  -1
# 465         0.266667    0.150000    0.166667                  -1
# 466         0.166667    0.300000    0.266667                  -3
# 467         0.333333    0.300000    0.533333                  -3
# 468         0.133333    0.300000    0.266667                  -1
# 469         0.266667    0.300000    0.533333                  -1
# 470         0.166667    0.300000    0.083333                  -3
# 472         0.133333    0.300000    0.083333                  -1
# 474         0.231579    0.347368    0.200000                   6
# 475         0.127451    0.205882    0.196078                  18
# 476         0.366667    0.216667    0.316667                  20
# 477         0.157895    0.228070    0.263158                   7
# 478         0.105263    0.210526    0.315789                   4
# 479         0.266667    0.300000    0.266667                  11
# 480         0.200000    0.166667    0.300000                   7
# 481         0.210526    0.223684    0.250000                  13
# 482         0.250000    0.291667    0.375000                  29
#
# [480 rows x 13 columns]

# %%
CombinedHomeandAway[CombinedHomeandAway['team_long_name']=='Arsenal']
# Out:
#    team_long_name  HomeDraws  Home_Wins  NumOfHomeGames  AwayDraws  \
# 19        Arsenal         34         97             152         39
#
#     Team.team_api_id  Away_Wins  NumOfAwayGames  %HomeWinSuccess  \
# 19              9825         73             152         0.638158
#
#     %AwayWinSuccess  %HomeDraws  %AwayDraws  Difference_of_Wins
# 19         0.480263    0.223684    0.256579                  24

# %%
CombinedHomeandAway.describe() 
#Means for Home and Away are out of the number teams.
# Out:
#         HomeDraws   Home_Wins  NumOfHomeGames   AwayDraws  Team.team_api_id  \
# count  480.000000  480.000000      480.000000  480.000000        480.000000
# mean    19.333333   31.910417       72.333333   18.381250      28064.993750
# std     12.354427   27.471798       45.998018   12.759967      68017.857319
# min      1.000000    1.000000       15.000000    1.000000       1601.000000
# 25%      8.000000    9.000000       30.000000    7.000000       8031.000000
# 50%     17.500000   23.000000       60.000000   16.000000       8559.500000
# 75%     31.000000   45.000000      110.000000   30.000000       9978.000000
# max     54.000000  131.000000      152.000000   57.000000     274581.000000
#
#        Away_Wins  NumOfAwayGames  %HomeWinSuccess  %AwayWinSuccess  \
# count  480.00000      480.000000       480.000000       480.000000
# mean    19.16250       72.333333         0.416809         0.236489
# std     19.18873       46.007639         0.190370         0.124612
# min      1.00000       15.000000         0.052632         0.052632
# 25%      5.00000       30.000000         0.300000         0.155556
# 50%     10.00000       60.000000         0.387993         0.210526
# 75%     26.00000      109.500000         0.517357         0.294118
# max    103.00000      153.000000         1.000000         0.684211
#
#        %HomeDraws  %AwayDraws  Difference_of_Wins
# count  480.000000  480.000000          480.000000
# mean     0.288607    0.263602           12.747917
# std      0.143604    0.116222           12.150973
# min      0.052632    0.058824           -6.000000
# 25%      0.210526    0.205399            4.000000
# 50%      0.264929    0.252982           11.000000
# 75%      0.315789    0.294118           21.000000
# max      0.733333    0.666667           51.000000

# %%
PopHomeWinsMean= sum(CombinedHomeandAway['Home_Wins'])/sum(CombinedHomeandAway['NumOfHomeGames'])
PopHomeWinsMean 
#Looking at total odds of winning at home games, using every teams success rate.
# Out:
# 0.4411578341013825

# %%
PopAwayWinsMean= sum(CombinedHomeandAway['Away_Wins'])/sum(CombinedHomeandAway['NumOfAwayGames'])
PopAwayWinsMean 
#Looking at total odds of winning at away games, using every teams success rate.
# Out:
# 0.26491935483870965

# %%
plt.hist(CombinedHomeandAway['Home_Wins']) 
plt.title("HomeWins Histogram")
plt.xlabel("Amount of Teams")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(CombinedHomeandAway['Away_Wins'])
plt.title("AwayWins Histogram")
plt.xlabel("Amount of Teams")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
CombinedHomeandAway['Difference_of_Wins'].plot(kind='hist', title= 'Home/Away Wins Difference Histogram')
#Histogram clearly shows that almost 60 teams had more away wins than home wins, while the rest all have more Home Wins

# %%
skewness= stats.skew(CombinedHomeandAway['Difference_of_Wins'])
kurtosis= stats.kurtosis(CombinedHomeandAway['Difference_of_Wins'])
skewness,kurtosis
#Positvely Higly skewed to the right, where our mean and median are greater than the mode. 
#Very low kurtosis, platykurtic distribution where our peak is lower and Broader than a Normal Distribution (fatter right-side tail).
# Out:
# (0.7101724108662442, -0.26541509539018815)

# %%
sns.distplot(CombinedHomeandAway['Difference_of_Wins'],
hist = True,kde = True, kde_kws={"color":"red","alpha":0.05,"label":"Kernel Density Estimation Plot"},
fit = stats.norm, fit_kws={"color":"green","alpha":0.05,"label":"Parametric fit"})

# %%
sns.kdeplot(CombinedHomeandAway['Difference_of_Wins'])
#KDE to show the % frequency of the amount of

# %%
ttest_rel(CombinedHomeandAway['Home_Wins'],CombinedHomeandAway['Away_Wins'])
#Repeated T-Test to account for using the same team twice for home and away. Measuring the average home and away wins, and 
#Checking whether they differ significantly across their games. Our very small pvalue and large T-stat shows that our 
#Null hypothesis (Home and away wins have no statistical difference in averages) is False and can be rejected.
# Out:
# Ttest_relResult(statistic=22.98522690915607, pvalue=2.4129466452683866e-79)
